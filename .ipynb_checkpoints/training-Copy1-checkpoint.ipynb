# %%
import csv

# %%
import imageio
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelBinarizer
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
model_dir = 'data/models/test1/'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# %% [markdown]
# ### Load from CSV

# %%
def load_images(data_dir, valid_cameras):
    df = pd.read_csv(data_dir+'driving_log.csv')
    images = []
    measurements = []

    def fetch_image(data_dir, source_path):
        filename = source_path.split('/')[-1]
        current_path = data_dir + 'IMG/' + filename
        return imageio.imread(current_path)

    def append_image(image, measurement):
        images.append(image)
        measurements.append(measurement)

        # flip image
        image_flipped = np.fliplr(image)
        measurement_flipped = -measurement
        images.append(image_flipped)
        measurements.append(measurement_flipped)

    for idx, row in df.iterrows():
        measurement = float(row[3])
        camera_map = { 1:0.2, 0:0, 2:-0.2 }
        if measurement <= 0 and np.random.rand() < 0.8:
            continue
        for c in valid_cameras:
            image = fetch_image(data_dir, row[c])
            append_image(image, measurement + camera_map[c])
            
    return images, measurements
    
def load_from_dir(data_dir, valid_cameras=[0], load_cached=True):
    if load_cached and os.path.exists(data_dir+'X_train.npy'):
        X_train = np.load(data_dir+'X_train.npy')
        y_train = np.load(data_dir+'y_train.npy')
    else:
        images, measurements = load_images(data_dir, valid_cameras)
        
        X_train = np.array(images)
        y_train = np.array(measurements)

        np.save(data_dir+'X_train.npy', X_train)
        np.save(data_dir+'y_train.npy', y_train)
    
    print('X_train:', X_train.shape)
    print('y_train:', y_train.shape)
    return X_train, y_train

# %%
X_train, y_train = load_from_dir('data/sample_data/', [0, 1, 2], False)
# Out:
# X_train: (18888, 160, 320, 3)
# y_train: (18888,)

# %% [markdown]
# ### Select images from each bucket for testing

# %%
y_train[:30]
# Out:
# array([ 0. , -0. ,  0.2, -0.2, -0.2,  0.2,  0. , -0. ,  0.2, -0.2, -0.2,
#         0.2,  0. , -0. ,  0.2, -0.2, -0.2,  0.2,  0. , -0. ,  0.2, -0.2,
#        -0.2,  0.2,  0. , -0. ,  0.2, -0.2, -0.2,  0.2])

# %%
print(y_train[2])
plt.imshow(X_train[2])
# Out:
# 0.2

# %% [markdown]
# ### Create Model

# %%
import keras
from keras.models import Sequential, Model
from keras.layers import Flatten, Dense, Lambda, Convolution2D, BatchNormalization, Input
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### NVIDIA Suggested network

# %%
model = Sequential()
model.add(Lambda(lambda x: x - 255.0 / 255.0, input_shape=(160,320,3)))
# model.add(Lambda(lambda x: x - 255.0 / 255.0, input_shape=(66,200,3))) # Checking with NVidia dimensions
model.add(keras.layers.Convolution2D(24, (5,5), strides=(2,2), activation='relu'))
model.add(keras.layers.Convolution2D(36, (5,5), strides=(2,2), activation='relu'))
model.add(keras.layers.Convolution2D(48, (5,5), strides=(2,2), activation='relu'))
model.add(keras.layers.Convolution2D(64, (3,3), strides=(1,1), activation='relu'))
model.add(keras.layers.Convolution2D(64, (3,3), strides=(1,1), activation='relu'))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1))

model.compile(loss='mse', optimizer=keras.optimizers.Adam(lr=.001))

# %%
model.summary()

# %%
model.fit(X_train, y_train, validation_split=0.2, shuffle=True, epochs=7)

model.save(model_dir+'nvidia_suggested_model.h5')

# %% [markdown]
# ### Dirt roads

# %%
X_train, y_train = load_from_dir('data/recorded_data/lap1_dirt_bridge/', [0, 1, 2], True)
model = keras.models.load_model('data/sample_data/'+'nvidia_suggested_model.h5')
# Out:
# X_train: (912, 160, 320, 3)
# y_train: (912,)

# %%
model.fit(X_train, y_train, validation_split=0.2, shuffle=True, epochs=7)

model.save(model_dir+'nvidia_suggested_model_dirt.h5')
# Out:
# Train on 729 samples, validate on 183 samples
# Epoch 1/7
# 729/729 [==============================] - 3s - loss: 0.0039 - val_loss: 0.0280
# Epoch 2/7
# 729/729 [==============================] - 0s - loss: 0.0016 - val_loss: 0.0264
# Epoch 3/7
# 729/729 [==============================] - 0s - loss: 0.0010 - val_loss: 0.0278
# Epoch 4/7
# 729/729 [==============================] - 0s - loss: 6.9188e-04 - val_loss: 0.0280
# Epoch 5/7
# 729/729 [==============================] - 0s - loss: 5.3267e-04 - val_loss: 0.0270
# Epoch 6/7
# 729/729 [==============================] - 0s - loss: 3.8811e-04 - val_loss: 0.0272
# Epoch 7/7
# 729/729 [==============================] - 0s - loss: 2.8127e-04 - val_loss: 0.0279

# %%
float(model.optimizer.lr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-0008a46ad65e> in <module>()
# ----> 1 float(model.optimizer.lr)
#
# TypeError: float() argument must be a string or a number, not 'Variable'

# %%
model.optimizer.lr = 0.0005
model.fit(X_train, y_train, validation_split=0.2, shuffle=True, epochs=7)

model.save(model_dir+'nvidia_suggested_model_dirt.h5')
# Out:
# Train on 729 samples, validate on 183 samples
# Epoch 1/7
# 729/729 [==============================] - 0s - loss: 2.0779e-04 - val_loss: 0.0281
# Epoch 2/7
# 729/729 [==============================] - 0s - loss: 1.5854e-04 - val_loss: 0.0279
# Epoch 3/7
# 729/729 [==============================] - 0s - loss: 1.2732e-04 - val_loss: 0.0279
# Epoch 4/7
# 729/729 [==============================] - 0s - loss: 1.0497e-04 - val_loss: 0.0286
# Epoch 5/7
# 729/729 [==============================] - 0s - loss: 7.9250e-05 - val_loss: 0.0287
# Epoch 6/7
# 729/729 [==============================] - 0s - loss: 6.6629e-05 - val_loss: 0.0285
# Epoch 7/7
# 729/729 [==============================] - 0s - loss: 6.0569e-05 - val_loss: 0.0286
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-c5926d4c5ea6> in <module>()
#       2 model.fit(X_train, y_train, validation_split=0.2, shuffle=True, epochs=7)
#       3
# ----> 4 model.save(model_dir+'nvidia_suggested_model_dirt2.h5')
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/engine/topology.py in save(self, filepath, overwrite, include_optimizer)
#    2551         """
#    2552         from ..models import save_model
# -> 2553         save_model(self, filepath, overwrite, include_optimizer)
#    2554
#    2555     def save_weights(self, filepath, overwrite=True):
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/models.py in save_model(model, filepath, overwrite, include_optimizer)
#     132                     'optimizer_config': {
#     133                         'class_name': model.optimizer.__class__.__name__,
# --> 134                         'config': model.optimizer.get_config()
#     135                     },
#     136                     'loss': model.loss,
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/optimizers.py in get_config(self)
#     446
#     447     def get_config(self):
# --> 448         config = {'lr': float(K.get_value(self.lr)),
#     449                   'beta_1': float(K.get_value(self.beta_1)),
#     450                   'beta_2': float(K.get_value(self.beta_2)),
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in get_value(x)
#    2128         A Numpy array.
#    2129     """
# -> 2130     return x.eval(session=get_session())
#    2131
#    2132
#
# AttributeError: 'float' object has no attribute 'eval'

# %% [markdown]
# ### Additional data

# %%
X_train, y_train = load_from_dir('data/recorded_data/lap1/', [0, 1, 2], False)

# %%
model.fit(X_train, y_train, validation_split=0.2, shuffle=True, epochs=7)

model.save(model_dir+'nvidia_suggested_model_self_lap1.h5')

# %% [markdown]
# ### Lap1 Mistakes

# %%
X_train, y_train = load_from_dir('data/recorded_data/lap1mistakes/', [0, 1, 2], False)

# %%
model.fit(X_train, y_train, validation_split=0.2, shuffle=True, epochs=6)

model.save(model_dir+'nvidia_suggested_model_self_lap1mistakes.h5')

# %% [markdown]
# ### Lap1 Reverse

# %%
X_train, y_train = load_from_dir('data/recorded_data/lap1reverse/', [0, 1, 2], False)

# %%
# model.optimizer.lr = 0.001
model.fit(X_train, y_train, validation_split=0.2, shuffle=True, epochs=5)

model.save(model_dir+'nvidia_suggested_model_self_lap1reverse.h5')
